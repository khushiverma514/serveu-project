# %%
quiz = {
    1 : {
        "question" : "What is the extension of python?",
        "answer" : ".py"
    },
    2 : {
        "question" : "which character is used to make a single line comment?",
        "answer" : "#"
    },
    3 : {
        "question" : "Which number does not have a reciprocal?",
        "answer" : "0"
    },
    4 : {
        "question" : "Greenland is part of which European nation?",
        "answer" : "Denmark"
    },
    5 : {
        "question" : "Which is the largest hot desert in the World?",
        "answer" : "Sahara Desert"
    },
    6 : {
        "question" : "Which is the biggest animal on earth?",
        "answer" : "Blue Whale"
    },
      7 : {
        "question" : "Who is known as the Father of Geometry?",
        "answer" : "Euclid"
    },
     8 : {
        "question" : "When is the National Girl Child Day in India celebrated?",
        "answer" : "24th January"
    },
      9 : {
        "question" : "Who is known as the Nightingale of India?",
        "answer" : "Sarojini Naidu"
    },
      10 : {
        "question" : "Who invented the light bulb?",
        "answer" : "Thomas Alva Edison"
    },
      11 : {
        "question" : "Which planet is also known as the red planet in our solar system?",
        "answer" : "Mars"
    },
      12 : {
        "question" : "Who discovered Penicillin?",
        "answer" : "Alexander Fleming"
    },
      13 : {
        "question" : "What is the largest moon of Saturn?",
        "answer" : "Titan"
    },
      14 : {
        "question" : "Who invented the Computer?",
        "answer" : "Charles Babbage"
    },
      15 : {
        "question" : "Who are the founders of Google?",
        "answer" : "Larry Page and Sergey Brin"
    },
      16 : {
        "question" : " Which is the longest river?",
        "answer" : "Nile"
    },
      17 : {
        "question" : "Who wrote Mahabharata?",
        "answer" : "Vyaas"
    },
      18 : {
        "question" : "Which organ is responsible for the purification of blood in the human body?",
        "answer" : "Kidney"
    },
     19 : {
        "question" : "What is the name of the tallest statue in the world that is located in Gujarat?",
        "answer" : "The Statue of Unity"
    },
    20 : {
        "question" : "Which is the largest nation in the world as per its geographical area?",
        "answer" : "Russia"
    },
    21 : {
        "question" : "Who is known as the Iron Man of India?",
        "answer" : "Sardar Vallabhbhai Patel"
    },
    22 : {
        "question" : "Which is the smallest ocean?",
        "answer" : "Arctic"
    },
    23 : {
        "question" : "Delhi is situated on the bank of which river?",
        "answer" : "Yamuna"
    },
    24 : {
        "question" : "Which city is called Pearl City?",
        "answer" : "Hyderabad"
    },
    25 : {
        "question" : "PV Sindhu is associated with which sport?",
        "answer" : "Badminton"
    },
    26 : {
        "question" : "A Place where dead bodies are kept:",
        "answer" : "Mortuary"
    },
    27 : {
        "question" : "The scientific study of an earthquake is called:",
        "answer" : "Seismology"
    },
    28 : {
        "question" : "Samudragupta is popularly known as:-",
        "answer" : "Napoleon of India"
    },
    29 : {
        "question" : "Lala Lajpat Rai is popularly known as:",
        "answer" : "Punjab Kesari"
    },
    30 : {
        "question" : "Name the author of Panchatantra.",
        "answer" : "Vishnu Sharma"
    },
    31 : {
        "question" : "Name the state which is the largest in India according to the area.",
        "answer" : "Rajasthan"
    },
    32 : {
        "question" : "Name the famous foundation established by Dayanand Saraswati.",
        "answer" : "Arya Samaj"
    },
    33 : {
        "question" : "How many fundamental rights are given in the Indian Constitution?",
        "answer" : "6"
    },
    34 : {
        "question" : "8th September is observed as:-",
        "answer" : "International Literacy Day"
    },
    35 : {
        "question" : "Which city of India is called the City of lakes?",
        "answer" : "Udaipur"
    },
    36 : {
        "question" : "Colt is the name of which animal’s baby?",
        "answer" : "Horse"
    },
    37 : {
        "question" : "Name the Defense Minister of India",
        "answer" : "Sh. Rajnath Singh"
    },
     38 : {
        "question" : "When was the battle of Buxar fought?",
        "answer" : "1764"
    },
     39 : {
        "question" : "Mool Shankar was the original of which famous personality?",
        "answer" : "Swami Dayanand Saraswati"
    },
    40 : {
        "question" : "How many members were there in the Constituent Assembly in the starting?",
        "answer" : "389"
    },
}
def check_ans(question, ans, attempts, score):
    """
    Takes the arguments, and confirms if the answer provided by user is correct.
    Converts all answers to lower case to make sure the quiz is not case sensitive.
    """
    if quiz[question]['answer'].lower() == ans.lower():
        print(f"Correct Answer! \nYour score is {score + 1}!")
        return True
    else:
        print(f"Wrong Answer :( \nYou have {attempts - 1} left! \nTry again...")
        return False


def print_dictionary():
    for question_id, ques_answer in quiz.items():
        for key in ques_answer:
            print(key + ':', ques_answer[key])


def intro_message():
    """
    Introduces user to the quiz and rules, and takes an input from customer to start the quiz.
    Returns true regardless of any key pressed.
    """
    print("Welcome to this KBC! \nAre you ready to test your knowledge about food?")
    print("There are a total of 40 questions, you can skip a question anytime by typing 'skip'")
    input("Press any key to start the fun ;) ")
    return True


# python project.py
intro = intro_message()
while True:
    score = 0
    for question in quiz:
        attempts = 2
        while attempts > 0:
            print(quiz[question]['question'])
            answer = input("Enter Answer (To move to the next question, type 'skip') : ")
            if answer == "skip":
                break
            check = check_ans(question, answer, attempts, score)
            if check:
                score += 1
                break
            attempts -= 1

    break

print(f"Your final score is {score}!\n\n")
print("Want to know the correct answers? Please see them below! ;)\n")
print_dictionary()
print("Thanks for playing!")
# Out:
# Welcome to this KBC!
# Are you ready to test your knowledge about food?
# There are a total of 40 questions, you can skip a question anytime by typing 'skip'
# Press any key to start the fun ;)
# What is the extension of python?
# Enter Answer (To move to the next question, type 'skip') : .py
# Correct Answer!
# Your score is 1!
# which character is used to make a single line comment?
# Enter Answer (To move to the next question, type 'skip') : #
# Correct Answer!
# Your score is 2!
# Which number does not have a reciprocal?
# Enter Answer (To move to the next question, type 'skip') : 0
# Correct Answer!
# Your score is 3!
# Greenland is part of which European nation?
# Enter Answer (To move to the next question, type 'skip') : denmark
# Correct Answer!
# Your score is 4!
# Which is the largest hot desert in the World?
# Enter Answer (To move to the next question, type 'skip') : Sahara
# Wrong Answer :(
# You have 1 left!
# Try again...
# ...
